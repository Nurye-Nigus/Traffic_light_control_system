# %%
# !nvidia-smi
# Out:
# 'nvidia-smi' is not recognized as an internal or external command,
# operable program or batch file.

# %%
#Ultralytics provides the infrastructure, frameworks, and tools to deploy and utilize computer vision algorithms and models effectively. YOLO, developed by Ultralytics, is an example of an algorithm within their suite of offerings

# !pip install ultralytics
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the 'c:\program files\python39\python.exe -m pip install --upgrade pip' command.
# ...

# %%
#just to check whether the model is detecting an image
# !yolo predict model=yolov8n.pt source="https://ultralytics.com/images/bus.jpg"
# Out:
# ...
# Ultralytics YOLOv8.1.15 🚀 Python-3.9.6 torch-2.2.0+cpu CPU (Intel Core(TM) i7-4600U 2.10GHz)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# ...
# image 1/1 c:\Users\hp\Desktop\software_HILCOE\traffic_light_control_system\static\notebooks\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 2467.6ms
# Speed: 335.4ms preprocess, 2467.6ms inference, 653.8ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs\detect\predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
#   0%|          | 0.00/6.23M [00:00<?, ?B/s]
#   2%|▏         | 144k/6.23M [00:00<00:06, 1.03MB/s]
#   4%|▍         | 248k/6.23M [00:00<00:06, 1.03MB/s]
#   6%|▌         | 384k/6.23M [00:00<00:05, 1.12MB/s]
#   8%|▊         | 512k/6.23M [00:00<00:05, 1.15MB/s]
#  11%|█         | 672k/6.23M [00:00<00:04, 1.28MB/s]
#  13%|█▎        | 832k/6.23M [00:01<00:15, 376kB/s]
#  16%|█▋        | 1.02M/6.23M [00:01<00:09, 560kB/s]
# ...

# %%
#this model detect 4 persons, 1 bus, 1 stop sign as displayed in the above result

# %%
# !pip install ultralytics==8.0.20
from IPython import display
display.clear_output()
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20  Python-3.9.6 torch-2.2.0+cpu CPU
# Setup complete  (4 CPUs, 7.9 GB RAM, 313.8/325.5 GB disk)

# %%
from ultralytics import YOLO
from IPython.display import display, Image

# %%
pwd
# Out:
# 'c:\\Users\\hp\\Desktop\\software_HILCOE\\traffic_light_control_system\\static\\notebooks'

# %%
import os

# Path to your training data directory
training_data_dir = 'c:\\Users\\hp\\Desktop\\software_HILCOE\\traffic_light_control_system\\static\\notebooks'

# Example of accessing files in the directory
file_list = os.listdir(training_data_dir)

# %%
# %cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 7AF2-43BA
#
#  Directory of c:\Users\hp\Desktop\software_HILCOE\traffic_light_control_system\static\notebooks
#
# 03/10/2024  01:45 PM    <DIR>          .
# 03/10/2024  01:45 PM    <DIR>          ..
# 03/10/2024  01:45 PM           487,438 bus.jpg
# 03/10/2024  01:45 PM    <DIR>          runs
# 02/18/2024  09:46 AM    <DIR>          traning_data
# 03/10/2024  06:43 AM         1,376,168 Yolo_V8.ipynb
# 03/10/2024  01:45 PM         6,534,387 yolov8n.pt
#                3 File(s)      8,397,993 bytes
#                4 Dir(s)  12,576,460,800 bytes free

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=c:\\Users\\hp\\Desktop\\software_HILCOE\\traffic_light_control_system\\static\\notebooks\\data.yaml epochs=25 imgsz=224 plots=True
# Out:
# Ultralytics YOLOv8.0.20  Python-3.9.6 torch-2.2.0+cpu CPU
# ...

# %%
#training for the second time 
# !yolo task=detect mode=train model=yolov8s.pt data=c:\\Users\\hp\\Desktop\\software_HILCOE\\traffic_light_control_system\\static\\notebooks\\data.yaml epochs=25 imgsz=224 plots=True
# Out:
# Ultralytics YOLOv8.0.20  Python-3.9.6 torch-2.2.0+cpu CPU
# ...

# %%
Image(filename='runs/detect/train8/confusion_matrix.png', width=600)

# %%
Image(filename='runs/detect/train8/results.png', width=600)

# %%
Image(filename='runs/detect/train8/F1_curve.png', width=600)

# %%
Image(filename='runs/detect/train8/P_curve.png', width=600)

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv('runs/detect/train8/results.csv')

# Display the DataFrame
df
# Out:
#                       epoch           train/box_loss           train/cls_loss  \
# 0                         0                  1.19090                  1.41980
# 1                         1                  1.00410                  0.82453
# 2                         2                  1.00430                  0.71626
# 3                         3                  1.01260                  0.65826
# 4                         4                  0.87254                  0.60871
# 5                         5                  0.94724                  0.59610
# 6                         6                  0.93199                  0.59349
# 7                         7                  0.90767                  0.64692
# 8                         8                  0.87528                  0.58992
# 9                         9                  0.95465                  0.54471
# 10                       10                  0.89097                  0.53583
# ...

# %%
Image(filename='runs/detect/train8/F1_curve.png', width=600)

# %%
Image(filename='runs/detect/train8/train_batch0.jpg', width=600)

# %%
Image(filename='runs/detect/train8/val_batch0_labels.jpg', width=600)

# %%
Image(filename='runs/detect/train8/val_batch1_labels.jpg', width=600)

# %%
#lets vaidate the custom model
# !yolo task=detect mode=val model=runs/detect/train8/weights/best.pt data=c:\\Users\\hp\\Desktop\\software_HILCOE\\traffic_light_control_system\\static\\notebooks\\data.yaml
# Out:
# 2024-03-10 17:12:59.041853: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2024-03-10 17:12:59.042800: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Ultralytics YOLOv8.0.20  Python-3.9.6 torch-2.2.0+cpu CPU
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#
# val: Scanning C:\Users\hp\Desktop\software_HILCOE\traffic_light_control_system\static\notebooks\traning_data\Cars\validation\labels.cache... 50 images, 0 backgrounds, 0 corrupt: 100%|██████████| 50/50 [00:00<?, ?it/s]
# val: Scanning C:\Users\hp\Desktop\software_HILCOE\traffic_light_control_system\static\notebooks\traning_data\Cars\validation\labels.cache... 50 images, 0 backgrounds, 0 corrupt: 100%|██████████| 50/50 [00:00<?, ?it/s]
#
# ...

# %%
# !yolo task=detect mode=predict model=runs/detect/train8/weights/best.pt conf=0.25 source = C:\Users\hp\Desktop\software_HILCOE\traffic_light_control_system\static\notebooks\traning_data\Cars\test\images
#now this pridicts the images based on the trained data this prediction data or testing the trained model
# Out:
# [WinError 3] The system cannot find the path specified: '/content/drive/MyDrive/Colab Notebooks'
# c:\Users\hp\Desktop\software_HILCOE\traffic_light_control_system\static\notebooks\runs\detect\train
# C:\Users\hp\AppData\Roaming\Python\Python39\site-packages\IPython\core\magics\osm.py:393: UserWarning: using bookmarks requires you to install the `pickleshare` library.
#   bkms = self.shell.db.get('bookmarks', {})
# 2024-03-10 17:10:36.757983: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2024-03-10 17:10:36.759012: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Ultralytics YOLOv8.0.20  Python-3.9.6 torch-2.2.0+cpu CPU
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
# ...
